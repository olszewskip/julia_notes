# %%
pwd()
# Out:
# "/home/olszewskip/Desktop/git-repos/julia_notes/Algorithms_for_Optimization_notes"

# %%
a = true
typeof(a)
# Out:
# Bool

# %%
typeof(2 // 4)
# Out:
# Rational{Int64}

# %%
1 < 2 > 3
# Out:
# false

# %%
using Plots
plotly()
plot(rand(20))
# Out:
# ┌ Info: Recompiling stale cache file /home/olszewskip/.julia/compiled/v1.1/Plots/ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1184
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="ee6071f0-45cd-498e-a9bd-b0de4ea542c1" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('ee6071f0-45cd-498e-a9bd-b0de4ea542c1');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             null,
# ...

# %%
plot(rand(20))
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="354e2047-512a-460a-a05d-c84dc4ecf449" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('354e2047-512a-460a-a05d-c84dc4ecf449');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "text": [
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
#             null,
# ...
